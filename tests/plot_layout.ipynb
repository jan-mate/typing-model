# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from src.utils.plot import plot_keyboard

plot_keyboard(
    '../data/layouts/qwerty_us.json', 
    layout_path='../data/layouts/layout_map.json',
    show_x_pos=False, 
    color_fingers=True,
    draw_split_line=True,
    modeled_only=True
)
