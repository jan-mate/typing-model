# %%
from google.colab import drive
import os
import sys

drive.mount('/content/drive')

# %cd /content
# !git clone https://github.com/jan-mate/typing-model.git

# %cd typing-model

# Link Drive data to local repo if needed
# !ln -s /content/drive/MyDrive/typing-model/enriched_data ./enriched_data

sys.path.append(f"/content/typing-model")

# !pip install optuna
# !pip install optuna-integration[lightgbm]
# !pip install pyphen

# %%
# %cd /content/typing-model
# !git pull

# %% [markdown]
# ## Linear Regression

# %%
# !python src/train_models/linear_regression/linreg_feature_selection.py

# %%
# !python src/train_models/linear_regression/linreg_hpo.py

# %%
# !python src/train_models/linear_regression/train_final_linreg.py

# %% [markdown]
# ## LGBM

# %%
# !python src/train_models/lgbm/feature_importance.py

# %%
# !python src/train_models/lgbm/lgbm_subset_features.py

# %%
# !python src/train_models/lgbm/lgbm_hpo.py

# %%
# !python src/train_models/lgbm/train_final_lgbm.py

# %% [markdown]
# ## MLP

# %%
# !python src/train_models/mlp/train_mlp_all_features.py

# %%
# !python src/train_models/mlp/mlp_feature_selection.py

# %%
# !python src/train_models/mlp/train_mlp_subset_features.py

# %%
# !python src/train_models/mlp/mlp_hpo.py

# %%
# !python src/train_models/mlp/dl_hpo.py

# %%
# !python src/train_models/mlp/train_final_ml.py

# %%
# !python src/train_models/mlp/linguistic_hpo.py

# %% [markdown]
# # Eval

# %%
# !python eval/hpo_phase1_analysis.py

# %%
# !python eval/evaluate_zero_shot.py

# %%
# !python eval/benchmark_inference_speed.py

# %%
# !python eval/model_bias.py

# %%
# !python eval/ensemble_variance.py

# %%
# !python eval/compare_layout_speed.py

# %%
# !python eval/dvorak_p_value_speedup.py

# %% [markdown]
# # Applications

# %% [markdown]
# ## Abbr_dict

# %%
# !python src/abbr_dict/precompute_speed.py
